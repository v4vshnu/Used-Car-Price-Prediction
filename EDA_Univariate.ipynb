# %% [markdown]
# <h1> Exploratory Data Analysis</h1>

# %% [markdown]
# <h6>Importing necessary libraries</h6>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h6>Reading the dataset</h6>

# %%
data=pd.read_csv("Data_Train.csv")

# %% [markdown]
# <h6>Displaying the dataset</h6>

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
data.tail()
# Out:
#                           Name   Location  Year  Kilometers_Driven Fuel_Type  \
# 6014          Maruti Swift VDI      Delhi  2014              27365    Diesel
# 6015  Hyundai Xcent 1.1 CRDi S     Jaipur  2015             100000    Diesel
# 6016     Mahindra Xylo D4 BSIV     Jaipur  2012              55000    Diesel
# 6017        Maruti Wagon R VXI    Kolkata  2013              46000    Petrol
# 6018     Chevrolet Beat Diesel  Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type     Mileage   Engine     Power  Seats  Price
# 6014       Manual      First   28.4 kmpl  1248 CC    74 bhp    5.0   4.75
# 6015       Manual      First   24.4 kmpl  1120 CC    71 bhp    5.0   4.00
# 6016       Manual     Second   14.0 kmpl  2498 CC   112 bhp    8.0   2.90
# 6017       Manual      First   18.9 kmpl   998 CC  67.1 bhp    5.0   2.65
# 6018       Manual      First  25.44 kmpl   936 CC  57.6 bhp    5.0   2.50

# %% [markdown]
# <h3>Analysing the dataset</h3>

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   2013.358199       5.873838e+04     5.278735     9.479468
# std       3.269742       9.126884e+04     0.808840    11.187917
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 6019 non-null object
# Location             6019 non-null object
# Year                 6019 non-null int64
# Kilometers_Driven    6019 non-null int64
# Fuel_Type            6019 non-null object
# Transmission         6019 non-null object
# Owner_Type           6019 non-null object
# Mileage              6017 non-null object
# Engine               5983 non-null object
# Power                5983 non-null object
# Seats                5977 non-null float64
# Price                6019 non-null float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 564.4+ KB

# %% [markdown]
# <h2> Grouping Categorical and Numerical Variables</h2>

# %%
columns = ['Name', 'Location','Fuel_Type','Transmission', 'Owner_Type', 'Year', 'Kilometers_Driven',  'Mileage', 'Engine', 'Power', 'Seats','Price']
data = data.reindex(columns=columns)

# %%
data.head()
# Out:
#                                Name    Location Fuel_Type Transmission  \
# 0            Maruti Wagon R LXI CNG      Mumbai       CNG       Manual
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune    Diesel       Manual
# 2                      Honda Jazz V     Chennai    Petrol       Manual
# 3                 Maruti Ertiga VDI     Chennai    Diesel       Manual
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore    Diesel    Automatic
#
#   Owner_Type  Year  Kilometers_Driven     Mileage   Engine      Power  Seats  \
# 0      First  2010              72000  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1      First  2015              41000  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2      First  2011              46000   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3      First  2012              87000  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4     Second  2013              40670   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# <h3>Analysing Categorical Variables</h3>

# %%
data.Name.nunique()
# Out:
# 1876

# %% [markdown]
# <h6>Inference</h6>
# <p> There are 1876 unique cars in the given dataset</p>

# %%
data.Location.nunique()
# Out:
# 11

# %%
data.Location.unique()
# Out:
# array(['Mumbai', 'Pune', 'Chennai', 'Coimbatore', 'Hyderabad', 'Jaipur',
#        'Kochi', 'Kolkata', 'Delhi', 'Bangalore', 'Ahmedabad'],
#       dtype=object)

# %% [markdown]
# <h6>Inference</h6>
# <p>These are the 11 unique locations in the dataset</p>

# %%
data.Location.value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %% [markdown]
# <h6>Inference</h6>
# <p>Decreasing Order of the distribution of cars in different Location</p>
# Most cars are from Mumbai and the least are from Ahmedabad

# %%
data.Fuel_Type.nunique()
# Out:
# 5

# %%
data.Fuel_Type.unique()
# Out:
# array(['CNG', 'Diesel', 'Petrol', 'LPG', 'Electric'], dtype=object)

# %%
data.Fuel_Type.value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %% [markdown]
# <h6>Inference</h6>
# <p>There are 5 Fuel types, majority being Diesel and minority being Electric</p>

# %%
data.Transmission.nunique()
# Out:
# 2

# %%
data.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data.Transmission.value_counts()
# Out:
# Manual       4299
# Automatic    1720
# Name: Transmission, dtype: int64

# %% [markdown]
# <h6>Inference</h6>
# <p> There are 2 modes of Transmission</p>
# Manual being the majority and Automatic the minority

# %%
data.Owner_Type.nunique()
# Out:
# 4

# %%
data.Owner_Type.unique()
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
data.Owner_Type.value_counts()
# Out:
# First             4929
# Second             968
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %% [markdown]
# <h6>Inference</h6>
# <p> Owner type are of 4 types with First being the majority</p>

# %% [markdown]
# <h3>Analysing Numerical Variables</h3>

# %%
data.Year.nunique()
# Out:
# 22

# %%
data.Year.unique()
# Out:
# array([2010, 2015, 2011, 2012, 2013, 2016, 2018, 2014, 2017, 2007, 2009,
#        2008, 2019, 2006, 2005, 2004, 2002, 2000, 2003, 1999, 2001, 1998],
#       dtype=int64)

# %%
data.Year.value_counts()
# Out:
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# 2008    174
# 2007    125
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 1998      4
# 2000      4
# 1999      2
# Name: Year, dtype: int64

# %% [markdown]
# <h6>Inference</h6>
# <p>There are car models over 22 years and majority of them are 2014 models</p>

# %%
data.Kilometers_Driven.nunique()
# Out:
# 3093

# %%
data.Kilometers_Driven.sort_values(ascending=True).head()
# Out:
# 1361     171
# 5606     600
# 1161    1000
# 1198    1000
# 173     1000
# Name: Kilometers_Driven, dtype: int64

# %%
data.Kilometers_Driven.sort_values(ascending=True).tail()
# Out:
# 3092     480000
# 358      620000
# 1860     720000
# 340      775000
# 2328    6500000
# Name: Kilometers_Driven, dtype: int64

# %% [markdown]
# <h6>Inference</h6>
# <p> These are the Kilometers Driven with highest being 6500000 and the lowest being 171</p>

# %%
data.Mileage.nunique()
# Out:
# 442

# %%
data.Mileage.isna().sum()
# Out:
# 2

# %% [markdown]
# <h6>Inference</h6>
# <p>There are 442 unique mileage entries and 2 missing entries</p>

# %%
data.Engine.nunique()
# Out:
# 146

# %%
data.Engine.sort_values(ascending=False).head()
# Out:
# 5207    999 CC
# 4370    999 CC
# 5944    999 CC
# 1271    999 CC
# 5200    999 CC
# Name: Engine, dtype: object

# %%
data.Engine.sort_values(ascending=False).tail()
# Out:
# 4712    NaN
# 4952    NaN
# 5015    NaN
# 5185    NaN
# 5270    NaN
# Name: Engine, dtype: object

# %%
data.Engine.isna().sum()
# Out:
# 36

# %% [markdown]
# <h6>Inference</h6>
# <p>There are 146 unique Engine values and 36 missing values</p>

# %%
data.Power.nunique()
# Out:
# 372

# %%
data.Power.sort_values(ascending=False).head()
# Out:
# 4744    null bhp
# 262     null bhp
# 245     null bhp
# 89      null bhp
# 424     null bhp
# Name: Power, dtype: object

# %%
data.Power.sort_values(ascending=False).head()
# Out:
# 4744    null bhp
# 262     null bhp
# 245     null bhp
# 89      null bhp
# 424     null bhp
# Name: Power, dtype: object

# %%
i=0
for power in data.Power:
    if power == "null bhp":
        i+=1
print(i)
# Out:
# 107

# %%
data.Power.isna().sum()
# Out:
# 36

# %% [markdown]
# <h6>Inference</h6>
# <p>There are 372 unique values with 36 missing values and 107 null values</p>

# %%
data.Seats.nunique()
# Out:
# 9

# %%
data.Seats.unique()
# Out:
# array([ 5.,  7.,  8.,  4.,  6.,  2., nan, 10.,  9.,  0.])

# %%
data.Seats.value_counts()
# Out:
# 5.0     5014
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
data.Seats.isna().sum()
# Out:
# 42

# %% [markdown]
# <h6>Inference</h6>
# <p>There are 9 unique seater cars in the given dataset and 42 missing values</p>

# %% [markdown]
# <h3>Removing anomalies and dropping missing values</h3>

# %%
data = data[data.Power!='null bhp']

# %%
data.Mileage = data.Mileage.str.replace(' km/kg',' kmpl')
data.Mileage = data.Mileage.str.replace(' kmpl','').astype(float)
data.Engine = data.Engine.str.replace(' CC','').astype(float)
data.Power = data.Power.str.replace(' bhp','').astype(float)

# %%
data=data.dropna(how='any')

# %% [markdown]
# <h3>Analysing...</h3>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5872 entries, 0 to 6018
# Data columns (total 12 columns):
# Name                 5872 non-null object
# Location             5872 non-null object
# Fuel_Type            5872 non-null object
# Transmission         5872 non-null object
# Owner_Type           5872 non-null object
# Year                 5872 non-null int64
# Kilometers_Driven    5872 non-null int64
# Mileage              5872 non-null float64
# Engine               5872 non-null float64
# Power                5872 non-null float64
# Seats                5872 non-null float64
# Price                5872 non-null float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 596.4+ KB

# %%
data.describe(include='all')
# Out:
#                           Name Location Fuel_Type Transmission Owner_Type  \
# count                     5872     5872      5872         5872       5872
# unique                    1811       11         4            2          4
# top     Mahindra XUV500 W8 2WD   Mumbai    Diesel       Manual      First
# freq                        49      775      3152         4170       4839
# mean                       NaN      NaN       NaN          NaN        NaN
# std                        NaN      NaN       NaN          NaN        NaN
# min                        NaN      NaN       NaN          NaN        NaN
# 25%                        NaN      NaN       NaN          NaN        NaN
# 50%                        NaN      NaN       NaN          NaN        NaN
# 75%                        NaN      NaN       NaN          NaN        NaN
# max                        NaN      NaN       NaN          NaN        NaN
#
#                Year  Kilometers_Driven      Mileage       Engine        Power  \
# ...

# %% [markdown]
# <h2>Graphical Representation</h2>

# %% [markdown]
# <h3>Univariate Analysis</h3>

# %%
import seaborn as sns

# %%
sns.heatmap(data.corr(),cmap='RdBu', annot=True, center=0)

# %% [markdown]
# <h6>Inference</h6>
# <p>Power and Engine plays a major role in determining the price of the car.</p>
# <p>Engine and Power are closely related</p>

# %%
sns.clustermap(data.corr(),cmap='RdBu',center=0)

# %%
data.Location.value_counts().plot(kind='bar',color='orange')

# %% [markdown]
# <h6>Inference</h6>
# <p>Most number of cars are from Mumbai and least are from Ahmedabad</p>

# %%
data.Fuel_Type.value_counts().plot(kind='bar')

# %% [markdown]
# <h6>Inference</h6>
# <p> Most number of cars are Diesel driven and only a few are LPG driven</p>

# %%
data.Transmission.value_counts().plot.pie(autopct="%1.1f%%")

# %% [markdown]
# <h6>Inference</h6>
# <p> Majority of the cars are manual(71%). Authomatic(29%)</p>

# %%
data.Owner_Type.value_counts().plot.pie(autopct="%1.1f%%")

# %% [markdown]
# <h6>Inference</h6>
# <p> Majority of the cars has owner type as First(82.4%) and Fourth and above is the minority(0.1%)</p>

# %%
sns.distplot(data.Year)

# %% [markdown]
# <h6>Inference</h6>
# <p> 2013 to 2018 car models are majority</p>
# <p>Models below 2008 are minority</p>

# %%
sns.kdeplot(data.Kilometers_Driven,shade=True,color='brown')

# %%
sns.distplot(data.Mileage,kde=False,hist=True,color='g')

# %% [markdown]
# <h6>Inference</h6>
# <p>Majority of cars have a mileage between 15 and 20 kmpl</p>

# %%
sns.countplot(data.Seats)

# %% [markdown]
# <h6>Inference</h6>
# <p> Majority of the cars are 5 seatres, 2 seatrers and 6 seaters are the minority</p>

# %%
sns.kdeplot(data.Power,shade=True,color='k')

# %% [markdown]
# <h6>Inference</h6>
# <p>Most cars have a power around 100 bhp</p>

# %% [markdown]
# <h3>Bivariate Analysis</h3>
# <h4>Pairplot anlysis</h4>

# %%
sns.pairplot(data,hue="Owner_Type")

# %%
sns.pairplot(data,hue="Transmission",palette="husl")

# %%
sns.pairplot(data,hue="Fuel_Type",palette="muted")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.color_palette("Set1", n_colors=11, desat=.5)
sns.pairplot(data, hue="Location",palette="Set1")
